# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
prem_data = pd.read_csv("Premier League 21-22 data.csv")
prem_data
# Out:
#            Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    13/08/2021       Brentford         Arsenal     2     0   H     1     0
# 1    14/08/2021      Man United           Leeds     5     1   H     1     0
# 2    14/08/2021         Burnley        Brighton     1     2   A     1     0
# 3    14/08/2021         Chelsea  Crystal Palace     3     0   H     2     0
# 4    14/08/2021         Everton     Southampton     3     1   H     0     1
# ..          ...             ...             ...   ...   ...  ..   ...   ...
# 375  22/05/2022  Crystal Palace      Man United     1     0   H     1     0
# 376  22/05/2022       Leicester     Southampton     4     1   H     0     0
# 377  22/05/2022       Liverpool          Wolves     3     1   H     1     1
# 378  22/05/2022        Man City     Aston Villa     3     2   H     0     1
# 379  22/05/2022         Norwich       Tottenham     0     5   A     0     2
#
#     HTR     Referee  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     H    M Oliver  ...    3    4  12   8   2   5   0   0   0   0
# 1     H   P Tierney  ...    8    3  11   9   5   4   1   2   0   0
# 2     H     D Coote  ...    3    8  10   7   7   6   2   1   0   0
# 3     H      J Moss  ...    6    1  15  11   5   2   0   0   0   0
# 4     A    A Madley  ...    6    3  13  15   6   8   2   0   0   0
# ..   ..         ...  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375   H  M Atkinson  ...    3    4  12  22   3   6   2   4   0   0
# 376   D      J Moss  ...    6    2  10   5   3   3   0   1   0   0
# 377   D    A Taylor  ...    8    5   6   3   5   3   1   0   0   0
# 378   A    M Oliver  ...    5    2   5  11  13   1   0   1   0   0
# 379   A  C Kavanagh  ...    0   13  13   7   3   2   3   1   0   0
#
# [380 rows x 22 columns]

# %%
prem_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      380 non-null    object
#  1   HomeTeam  380 non-null    object
#  2   AwayTeam  380 non-null    object
#  3   FTHG      380 non-null    int64
#  4   FTAG      380 non-null    int64
#  5   FTR       380 non-null    object
#  6   HTHG      380 non-null    int64
#  7   HTAG      380 non-null    int64
#  8   HTR       380 non-null    object
#  9   Referee   380 non-null    object
#  10  HS        380 non-null    int64
#  11  AS        380 non-null    int64
#  12  HST       380 non-null    int64
#  13  AST       380 non-null    int64
#  14  HF        380 non-null    int64
#  15  AF        380 non-null    int64
#  16  HC        380 non-null    int64
#  17  AC        380 non-null    int64
#  18  HY        380 non-null    int64
#  19  AY        380 non-null    int64
#  20  HR        380 non-null    int64
#  21  AR        380 non-null    int64
# dtypes: int64(16), object(6)
# memory usage: 65.4+ KB

# %%
prem_data.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
#        'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC',
#        'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
prem_data.columns = ['date', 'home_team', 'away_team', 'full_time_home_goals', 
 'full_time_away_goals', 'full_time_result', 'half_time_home_goals', 
 'half_time_away_goals','half_time_results', 'referee',
 'home_shot', 'away_shot', 'home_shot_target', 'away_shot_target',
 'home_fouls', 'away_fouls', 'home_corner', 'away_corner', 
 'home_yellow', 'away_yellow', 'home_red', 'away_red']

# %%
prem_data.head()
# Out:
#          date   home_team       away_team  full_time_home_goals  \
# 0  13/08/2021   Brentford         Arsenal                     2
# 1  14/08/2021  Man United           Leeds                     5
# 2  14/08/2021     Burnley        Brighton                     1
# 3  14/08/2021     Chelsea  Crystal Palace                     3
# 4  14/08/2021     Everton     Southampton                     3
#
#    full_time_away_goals full_time_result  half_time_home_goals  \
# 0                     0                H                     1
# 1                     1                H                     1
# 2                     2                A                     1
# 3                     0                H                     2
# 4                     1                H                     0
#
#    half_time_away_goals half_time_results    referee  ...  home_shot_target  \
# 0                     0                 H   M Oliver  ...                 3
# 1                     0                 H  P Tierney  ...                 8
# 2                     0                 H    D Coote  ...                 3
# 3                     0                 H     J Moss  ...                 6
# 4                     1                 A   A Madley  ...                 6
#
#    away_shot_target  home_fouls  away_fouls  home_corner  away_corner  \
# 0                 4          12           8            2            5
# 1                 3          11           9            5            4
# 2                 8          10           7            7            6
# 3                 1          15          11            5            2
# 4                 3          13          15            6            8
#
#    home_yellow  away_yellow  home_red  away_red
# 0            0            0         0         0
# 1            1            2         0         0
# 2            2            1         0         0
# 3            0            0         0         0
# 4            2            0         0         0
#
# [5 rows x 22 columns]

# %%
prem_data.columns = prem_data.columns.str.replace("home", "h").str.replace("away", "a")
prem_data.head()
# Out:
#          date      h_team          a_team  full_time_h_goals  \
# 0  13/08/2021   Brentford         Arsenal                  2
# 1  14/08/2021  Man United           Leeds                  5
# 2  14/08/2021     Burnley        Brighton                  1
# 3  14/08/2021     Chelsea  Crystal Palace                  3
# 4  14/08/2021     Everton     Southampton                  3
#
#    full_time_a_goals full_time_result  half_time_h_goals  half_time_a_goals  \
# 0                  0                H                  1                  0
# 1                  1                H                  1                  0
# 2                  2                A                  1                  0
# 3                  0                H                  2                  0
# 4                  1                H                  0                  1
#
#   half_time_results    referee  ...  h_shot_target  a_shot_target  h_fouls  \
# 0                 H   M Oliver  ...              3              4       12
# 1                 H  P Tierney  ...              8              3       11
# 2                 H    D Coote  ...              3              8       10
# 3                 H     J Moss  ...              6              1       15
# 4                 A   A Madley  ...              6              3       13
#
#    a_fouls  h_corner  a_corner  h_yellow  a_yellow  h_red  a_red
# 0        8         2         5         0         0      0      0
# 1        9         5         4         1         2      0      0
# 2        7         7         6         2         1      0      0
# 3       11         5         2         0         0      0      0
# 4       15         6         8         2         0      0      0
#
# [5 rows x 22 columns]

# %%
# setting the date to pandas date-time format
prem_data["date"] = pd.to_datetime(prem_data["date"], infer_datetime_format= True)
prem_data.head()
# Out:
#         date      h_team          a_team  full_time_h_goals  \
# 0 2021-08-13   Brentford         Arsenal                  2
# 1 2021-08-14  Man United           Leeds                  5
# 2 2021-08-14     Burnley        Brighton                  1
# 3 2021-08-14     Chelsea  Crystal Palace                  3
# 4 2021-08-14     Everton     Southampton                  3
#
#    full_time_a_goals full_time_result  half_time_h_goals  half_time_a_goals  \
# 0                  0                H                  1                  0
# 1                  1                H                  1                  0
# 2                  2                A                  1                  0
# 3                  0                H                  2                  0
# 4                  1                H                  0                  1
#
#   half_time_results    referee  ...  h_shot_target  a_shot_target  h_fouls  \
# 0                 H   M Oliver  ...              3              4       12
# 1                 H  P Tierney  ...              8              3       11
# 2                 H    D Coote  ...              3              8       10
# 3                 H     J Moss  ...              6              1       15
# 4                 A   A Madley  ...              6              3       13
#
#    a_fouls  h_corner  a_corner  h_yellow  a_yellow  h_red  a_red
# 0        8         2         5         0         0      0      0
# 1        9         5         4         1         2      0      0
# 2        7         7         6         2         1      0      0
# 3       11         5         2         0         0      0      0
# 4       15         6         8         2         0      0      0
#
# [5 rows x 22 columns]

# %%
# checking for null values
prem_data.isnull().sum()
# Out:
# date                 0
# h_team               0
# a_team               0
# full_time_h_goals    0
# full_time_a_goals    0
# full_time_result     0
# half_time_h_goals    0
# half_time_a_goals    0
# half_time_results    0
# referee              0
# h_shot               0
# a_shot               0
# h_shot_target        0
# a_shot_target        0
# h_fouls              0
# a_fouls              0
# h_corner             0
# a_corner             0
# h_yellow             0
# a_yellow             0
# h_red                0
# a_red                0
# dtype: int64

# %%
# seeing the home teams occuring only once
prem_data["h_team"].unique()
# Out:
# array(['Brentford', 'Man United', 'Burnley', 'Chelsea', 'Everton',
#        'Leicester', 'Watford', 'Norwich', 'Newcastle', 'Tottenham',
#        'Liverpool', 'Aston Villa', 'Crystal Palace', 'Leeds', 'Man City',
#        'Brighton', 'Southampton', 'Wolves', 'Arsenal', 'West Ham'],
#       dtype=object)

# %%
# seeing how many times each team occurs in the home team column
prem_data["h_team"].value_counts()
# Out:
# Brentford         19
# Man United        19
# Arsenal           19
# Wolves            19
# Southampton       19
# Brighton          19
# Man City          19
# Leeds             19
# Crystal Palace    19
# Aston Villa       19
# Liverpool         19
# Tottenham         19
# Newcastle         19
# Norwich           19
# Watford           19
# Leicester         19
# Everton           19
# Chelsea           19
# Burnley           19
# West Ham          19
# Name: h_team, dtype: int64

# %%
# seeing how many times each team occurs in the home team column
prem_data["a_team"].value_counts()
# Out:
# Arsenal           19
# Leeds             19
# Chelsea           19
# Tottenham         19
# Man United        19
# Watford           19
# Norwich           19
# Everton           19
# Brentford         19
# Newcastle         19
# Burnley           19
# Man City          19
# West Ham          19
# Liverpool         19
# Aston Villa       19
# Wolves            19
# Southampton       19
# Crystal Palace    19
# Brighton          19
# Leicester         19
# Name: a_team, dtype: int64

# %% [markdown]
# ### Creating a Premier Leauge Table from the data

# %%
# obtaining the unique teams
prem_table = pd.DataFrame(prem_data["h_team"].unique(), columns = ["teams"])
prem_table
# Out:
#              teams
# 0        Brentford
# 1       Man United
# 2          Burnley
# 3          Chelsea
# 4          Everton
# 5        Leicester
# 6          Watford
# 7          Norwich
# 8        Newcastle
# 9        Tottenham
# 10       Liverpool
# 11     Aston Villa
# 12  Crystal Palace
# 13           Leeds
# 14        Man City
# 15        Brighton
# 16     Southampton
# 17          Wolves
# 18         Arsenal
# 19        West Ham

# %%
# adding more columns
prem_table[['Played','Win','Draw','Loss','GF','GA','GD','Points']] = 0
prem_table
# Out:
#              teams  Played  Win  Draw  Loss  GF  GA  GD  Points
# 0        Brentford       0    0     0     0   0   0   0       0
# 1       Man United       0    0     0     0   0   0   0       0
# 2          Burnley       0    0     0     0   0   0   0       0
# 3          Chelsea       0    0     0     0   0   0   0       0
# 4          Everton       0    0     0     0   0   0   0       0
# 5        Leicester       0    0     0     0   0   0   0       0
# 6          Watford       0    0     0     0   0   0   0       0
# 7          Norwich       0    0     0     0   0   0   0       0
# 8        Newcastle       0    0     0     0   0   0   0       0
# 9        Tottenham       0    0     0     0   0   0   0       0
# 10       Liverpool       0    0     0     0   0   0   0       0
# 11     Aston Villa       0    0     0     0   0   0   0       0
# 12  Crystal Palace       0    0     0     0   0   0   0       0
# 13           Leeds       0    0     0     0   0   0   0       0
# 14        Man City       0    0     0     0   0   0   0       0
# 15        Brighton       0    0     0     0   0   0   0       0
# 16     Southampton       0    0     0     0   0   0   0       0
# 17          Wolves       0    0     0     0   0   0   0       0
# 18         Arsenal       0    0     0     0   0   0   0       0
# 19        West Ham       0    0     0     0   0   0   0       0

# %%
# setting the teams column as the index column
prem_table = prem_table.set_index("teams")
prem_table
# Out:
#                 Played  Win  Draw  Loss  GF  GA  GD  Points
# teams
# Brentford            0    0     0     0   0   0   0       0
# Man United           0    0     0     0   0   0   0       0
# Burnley              0    0     0     0   0   0   0       0
# Chelsea              0    0     0     0   0   0   0       0
# Everton              0    0     0     0   0   0   0       0
# Leicester            0    0     0     0   0   0   0       0
# Watford              0    0     0     0   0   0   0       0
# Norwich              0    0     0     0   0   0   0       0
# Newcastle            0    0     0     0   0   0   0       0
# Tottenham            0    0     0     0   0   0   0       0
# Liverpool            0    0     0     0   0   0   0       0
# Aston Villa          0    0     0     0   0   0   0       0
# Crystal Palace       0    0     0     0   0   0   0       0
# Leeds                0    0     0     0   0   0   0       0
# Man City             0    0     0     0   0   0   0       0
# Brighton             0    0     0     0   0   0   0       0
# Southampton          0    0     0     0   0   0   0       0
# Wolves               0    0     0     0   0   0   0       0
# Arsenal              0    0     0     0   0   0   0       0
# West Ham             0    0     0     0   0   0   0       0

# %%
# filling the table by looping through the index
for i in prem_data.index: # i here represents the index from the imported dataframe
    home = prem_data.loc[i,"h_team"]
    away = prem_data.loc[i, "a_team"]
    prem_table.loc[home, "Played"] += 1
    prem_table.loc[away, "Played"] += 1
#     using if statements to update rsults based on  home wins
    if prem_data.loc[i,"full_time_result"] == "H":
        prem_table.loc[home, "Win"] += 1
        prem_table.loc[home, "Points"] += 3
        prem_table.loc[away, "Loss"] += 1
#     using if statements to update results based on away wins
    elif prem_data.loc[i, "full_time_result"] == "A":
        prem_table.loc[away, "Win"] += 1
        prem_table.loc[home, "Loss"] += 1
        prem_table.loc[away, "Points"] += 3 
#     using if statement to update the results based on draws
    elif prem_data.loc[i,"full_time_result"] == "D":
        prem_table.loc[home, "Draw"] += 1
        prem_table.loc[away, "Draw"] += 1
        prem_table.loc[home, "Points"] += 1
        prem_table.loc[away, "Points"] += 1  
#     updating results based on goals
    home_goals = prem_data.loc[i, "full_time_h_goals"]
    away_goals = prem_data.loc[i, "full_time_a_goals"]
    prem_table.loc[home, "GF"] += home_goals
    prem_table.loc[away,"GF"] += away_goals
    prem_table.loc[home, "GA"] += away_goals
    prem_table.loc[away, "GA"] += home_goals
#     updating the goal difference 
prem_table["GD"] = prem_table["GF"] - prem_table["GA"]
# sorting according to goal difference first then points
prem_table = prem_table.sort_values("GD", ascending = False).sort_values("Points", ascending = False)
prem_table.reset_index(inplace = True)
prem_table
# Out:
#              teams  Played  Win  Draw  Loss  GF  GA  GD  Points
# 0         Man City      38   29     6     3  99  26  73      93
# 1        Liverpool      38   28     8     2  94  26  68      92
# 2          Chelsea      38   21    11     6  76  33  43      74
# 3        Tottenham      38   22     5    11  69  40  29      71
# 4          Arsenal      38   22     3    13  61  48  13      69
# 5       Man United      38   16    10    12  57  57   0      58
# 6         West Ham      38   16     8    14  60  51   9      56
# 7        Leicester      38   14    10    14  62  59   3      52
# 8           Wolves      38   15     6    17  38  43  -5      51
# 9         Brighton      38   12    15    11  42  44  -2      51
# 10       Newcastle      38   13    10    15  44  62 -18      49
# 11  Crystal Palace      38   11    15    12  50  46   4      48
# 12       Brentford      38   13     7    18  48  56  -8      46
# 13     Aston Villa      38   13     6    19  52  54  -2      45
# 14     Southampton      38    9    13    16  43  67 -24      40
# 15         Everton      38   11     6    21  43  66 -23      39
# 16           Leeds      38    9    11    18  42  79 -37      38
# 17         Burnley      38    7    14    17  34  53 -19      35
# 18         Watford      38    6     5    27  34  77 -43      23
# 19         Norwich      38    5     7    26  23  84 -61      22

# %% [markdown]
# ### Which team commited the most fouls

# %%
prem_data.head()
# Out:
#         date      h_team          a_team  full_time_h_goals  \
# 0 2021-08-13   Brentford         Arsenal                  2
# 1 2021-08-14  Man United           Leeds                  5
# 2 2021-08-14     Burnley        Brighton                  1
# 3 2021-08-14     Chelsea  Crystal Palace                  3
# 4 2021-08-14     Everton     Southampton                  3
#
#    full_time_a_goals full_time_result  half_time_h_goals  half_time_a_goals  \
# 0                  0                H                  1                  0
# 1                  1                H                  1                  0
# 2                  2                A                  1                  0
# 3                  0                H                  2                  0
# 4                  1                H                  0                  1
#
#   half_time_results    referee  ...  h_shot_target  a_shot_target  h_fouls  \
# 0                 H   M Oliver  ...              3              4       12
# 1                 H  P Tierney  ...              8              3       11
# 2                 H    D Coote  ...              3              8       10
# 3                 H     J Moss  ...              6              1       15
# 4                 A   A Madley  ...              6              3       13
#
#    a_fouls  h_corner  a_corner  h_yellow  a_yellow  h_red  a_red
# 0        8         2         5         0         0      0      0
# 1        9         5         4         1         2      0      0
# 2        7         7         6         2         1      0      0
# 3       11         5         2         0         0      0      0
# 4       15         6         8         2         0      0      0
#
# [5 rows x 22 columns]

# %%
prem_data.columns
# Out:
# Index(['date', 'h_team', 'a_team', 'full_time_h_goals', 'full_time_a_goals',
#        'full_time_result', 'half_time_h_goals', 'half_time_a_goals',
#        'half_time_results', 'referee', 'h_shot', 'a_shot', 'h_shot_target',
#        'a_shot_target', 'h_fouls', 'a_fouls', 'h_corner', 'a_corner',
#        'h_yellow', 'a_yellow', 'h_red', 'a_red'],
#       dtype='object')

# %%
f = prem_data[["h_team", "a_team", "h_fouls", "a_fouls"]]
f
# Out:
#              h_team          a_team  h_fouls  a_fouls
# 0         Brentford         Arsenal       12        8
# 1        Man United           Leeds       11        9
# 2           Burnley        Brighton       10        7
# 3           Chelsea  Crystal Palace       15       11
# 4           Everton     Southampton       13       15
# ..              ...             ...      ...      ...
# 375  Crystal Palace      Man United       12       22
# 376       Leicester     Southampton       10        5
# 377       Liverpool          Wolves        6        3
# 378        Man City     Aston Villa        5       11
# 379         Norwich       Tottenham       13        7
#
# [380 rows x 4 columns]

# %%
table = pd.DataFrame(f["h_team"].unique(), columns = ["Teams"])
table
# Out:
#              Teams
# 0        Brentford
# 1       Man United
# 2          Burnley
# 3          Chelsea
# 4          Everton
# 5        Leicester
# 6          Watford
# 7          Norwich
# 8        Newcastle
# 9        Tottenham
# 10       Liverpool
# 11     Aston Villa
# 12  Crystal Palace
# 13           Leeds
# 14        Man City
# 15        Brighton
# 16     Southampton
# 17          Wolves
# 18         Arsenal
# 19        West Ham

# %%
table["fouls"] = 0
table.set_index("Teams", inplace=True)
table
# Out:
#                 fouls
# Teams
# Brentford           0
# Man United          0
# Burnley             0
# Chelsea             0
# Everton             0
# Leicester           0
# Watford             0
# Norwich             0
# Newcastle           0
# Tottenham           0
# Liverpool           0
# Aston Villa         0
# Crystal Palace      0
# Leeds               0
# Man City            0
# Brighton            0
# Southampton         0
# Wolves              0
# Arsenal             0
# West Ham            0

# %%
f.head()
# Out:
#        h_team          a_team  h_fouls  a_fouls
# 0   Brentford         Arsenal       12        8
# 1  Man United           Leeds       11        9
# 2     Burnley        Brighton       10        7
# 3     Chelsea  Crystal Palace       15       11
# 4     Everton     Southampton       13       15

# %%
# looping through the data and updating the fouls
for i in f.index:
    home = f.loc[i, "h_team"]
    away = f.loc[i, "a_team"]
    home_fouls = f.loc[i, "h_fouls"]
    away_fouls = f.loc[i, "a_fouls"]
    table.loc[home, "fouls"] += home_fouls
    table.loc[away, "fouls"] += away_fouls
table = table.sort_values("fouls", ascending=False) # sorting from team with most fouls to least
table.reset_index(inplace=True)
table
# Out:
#              Teams  fouls
# 0            Leeds    469
# 1          Watford    440
# 2   Crystal Palace    415
# 3          Chelsea    409
# 4      Southampton    402
# 5      Aston Villa    401
# 6       Man United    395
# 7          Burnley    394
# 8         Brighton    393
# 9        Newcastle    391
# 10       Tottenham    386
# 11       Brentford    371
# 12         Everton    368
# 13          Wolves    365
# 14         Arsenal    363
# 15       Liverpool    363
# 16         Norwich    356
# 17       Leicester    356
# 18        West Ham    324
# 19        Man City    320

# %% [markdown]
# Plotting a bar plot

# %%
plt.figure(figsize = (22,10))
sns.barplot(x = "Teams",y = "fouls", data = table)
# Out:
# <AxesSubplot:xlabel='Teams', ylabel='fouls'>

# %% [markdown]
# Making it a horizontal barplot

# %%
plt.figure(figsize = (15,8))
sns.barplot(y = "Teams",x = "fouls", data = table)
# Out:
# <AxesSubplot:xlabel='fouls', ylabel='Teams'>
